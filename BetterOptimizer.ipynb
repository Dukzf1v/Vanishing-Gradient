# %% [markdown]
# <a href="https://colab.research.google.com/github/Dukzf1v/Vanishing-Gradient/blob/main/BetterOptimizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import random
from torch import nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
import torchvision
from torchvision.datasets import FashionMNIST
import matplotlib.pyplot as plt
import torchvision.transforms as transforms
import numpy as np

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
def set_seed(seed):
  random.seed(seed)
  np.random.seed(seed)
  torch.manual_seed(seed)
  torch.cuda.manual_seed(seed)
  torch.cuda.manual_seed_all(seed)
  torch.backends.cudnn.deterministic = True
  torch.backends.cudnn.benchmark = False

SEED = 42
set_seed(SEED)

# %% [markdown]
# ## Prepare dataset

# %%
batch_size = 512

train_dataset = FashionMNIST(
    './data',
    train=True,
    download=True,
    transform=transforms.ToTensor()
)

test_dataset = FashionMNIST(
    './data',
    train=False,
    download=True,
    transform=transforms.ToTensor()
)

train_ratio = 0.9
train_size = int(len(train_dataset) * train_ratio)
val_size = len(train_dataset) - train_size

train_subset, val_subset = random_split(train_dataset, [train_size, val_size])

train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_subset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print(f"Train size: {len(train_subset)}")
print(f"Validation size: {len(val_subset)}")
print(f"Test size: {len(test_dataset)}")
# Out:
# Train size: 54000
# Validation size: 6000
# Test size: 10000

# %% [markdown]
# ## 2. Build MLP network

# %%
class MLP(nn.Module):
  def __init__(self, input_dims, hidden_dims, output_dims):
    super(MLP, self).__init__()
    self.layer1 = nn.Linear(input_dims, hidden_dims)
    self.layer2 = nn.Linear(hidden_dims, hidden_dims)
    self.layer3 = nn.Linear(hidden_dims, hidden_dims)
    self.layer4 = nn.Linear(hidden_dims, hidden_dims)
    self.layer5 = nn.Linear(hidden_dims, hidden_dims)
    self.layer6 = nn.Linear(hidden_dims, hidden_dims)
    self.layer7 = nn.Linear(hidden_dims, hidden_dims)
    self.output = nn.Linear(hidden_dims, output_dims)

    for module in self.modules():
      if isinstance(module,nn.Linear):
        nn.init.normal_(module.weight,mean=0.0,std=0.05)
        nn.init.constant_(module.bias,0.0)

  def forward(self, x):
    x = nn.Flatten()(x)
    x = self.layer1(x)
    x = nn.Sigmoid()(x)
    x = self.layer2(x)
    x = nn.Sigmoid()(x)
    x = self.layer3(x)
    x = nn.Sigmoid()(x)
    x = self.layer4(x)
    x = nn.Sigmoid()(x)
    x = self.layer5(x)
    x = nn.Sigmoid()(x)
    x = self.layer6(x)
    x = nn.Sigmoid()(x)
    x = self.layer7(x)
    x = nn.Sigmoid()(x)
    out = self.output(x)

    return out

# %%
input_dims = 784
hidden_dims = 128
output_dims = 10

model = MLP(input_dims=input_dims,
            hidden_dims=hidden_dims,
            output_dims=output_dims).to(device)

criterion = nn.CrossEntropyLoss()
lr = 1e-3
optimizer = optim.Adam(model.parameters(), lr=lr)

# %% [markdown]
# ## 3.Training

# %%
epochs = 100
train_loss_lst = []
train_acc_lst = []
val_loss_lst = []
val_acc_lst = []

for epoch in range(epochs):
    train_loss = 0.0
    train_acc = 0.0
    count = 0

    model.train()
    for X_train, y_train in train_loader:
        X_train, y_train = X_train.to(device), y_train.to(device)
        optimizer.zero_grad()
        outputs = model(X_train)
        loss = criterion(outputs, y_train)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        train_acc += (torch.argmax(outputs, 1) == y_train).sum().item()
        count += len(y_train)

    train_loss /= len(train_loader)
    train_loss_lst.append(train_loss)
    train_acc /= count
    train_acc_lst.append(train_acc)

    val_loss = 0.0
    val_acc = 0.0
    count = 0
    model.eval()
    with torch.no_grad():
        for X_val, y_val in val_loader:
            X_val, y_val = X_val.to(device), y_val.to(device)
            outputs = model(X_val)
            loss = criterion(outputs, y_val)
            val_loss += loss.item()
            val_acc += (torch.argmax(outputs, 1) == y_val).sum().item()
            count += len(y_val)

    val_loss /= len(test_loader)
    val_loss_lst.append(val_loss)
    val_acc /= count
    val_acc_lst.append(val_acc)

    print(f"EPOCH {epoch+1}/{epochs}, Train_Loss: {train_loss:.4f}, Train_Acc: {train_acc:.4f}, Validation Loss: {val_loss:.4f}, Val_Acc: {val_acc:.4f}")
# Out:
# EPOCH 1/100, Train_Loss: 2.1762, Train_Acc: 0.1366, Validation Loss: 1.0266, Val_Acc: 0.1938
# EPOCH 2/100, Train_Loss: 1.7038, Train_Acc: 0.1983, Validation Loss: 1.0153, Val_Acc: 0.2092
# EPOCH 3/100, Train_Loss: 1.6884, Train_Acc: 0.1999, Validation Loss: 1.0167, Val_Acc: 0.2020
# EPOCH 4/100, Train_Loss: 1.6837, Train_Acc: 0.2003, Validation Loss: 1.0138, Val_Acc: 0.1918
# EPOCH 5/100, Train_Loss: 1.6736, Train_Acc: 0.2011, Validation Loss: 1.0001, Val_Acc: 0.2200
# EPOCH 6/100, Train_Loss: 1.5294, Train_Acc: 0.2828, Validation Loss: 0.8837, Val_Acc: 0.2903
# EPOCH 7/100, Train_Loss: 1.3361, Train_Acc: 0.3817, Validation Loss: 0.7061, Val_Acc: 0.4498
# EPOCH 8/100, Train_Loss: 1.0818, Train_Acc: 0.4914, Validation Loss: 0.6199, Val_Acc: 0.5225
# EPOCH 9/100, Train_Loss: 0.9790, Train_Acc: 0.5603, Validation Loss: 0.5506, Val_Acc: 0.6370
# EPOCH 10/100, Train_Loss: 0.8265, Train_Acc: 0.6500, Validation Loss: 0.4803, Val_Acc: 0.6842
# EPOCH 11/100, Train_Loss: 0.7624, Train_Acc: 0.6945, Validation Loss: 0.4473, Val_Acc: 0.7242
# EPOCH 12/100, Train_Loss: 0.6817, Train_Acc: 0.7653, Validation Loss: 0.4044, Val_Acc: 0.7763
# EPOCH 13/100, Train_Loss: 0.6198, Train_Acc: 0.7864, Validation Loss: 0.3927, Val_Acc: 0.7783
# EPOCH 14/100, Train_Loss: 0.5900, Train_Acc: 0.7948, Validation Loss: 0.3840, Val_Acc: 0.7850
# EPOCH 15/100, Train_Loss: 0.5638, Train_Acc: 0.8031, Validation Loss: 0.3631, Val_Acc: 0.7968
# EPOCH 16/100, Train_Loss: 0.5570, Train_Acc: 0.8054, Validation Loss: 0.3605, Val_Acc: 0.8000
# EPOCH 17/100, Train_Loss: 0.5327, Train_Acc: 0.8146, Validation Loss: 0.3537, Val_Acc: 0.8027
# EPOCH 18/100, Train_Loss: 0.5241, Train_Acc: 0.8181, Validation Loss: 0.3447, Val_Acc: 0.8117
# EPOCH 19/100, Train_Loss: 0.5150, Train_Acc: 0.8218, Validation Loss: 0.3514, Val_Acc: 0.8038
# EPOCH 20/100, Train_Loss: 0.5020, Train_Acc: 0.8261, Validation Loss: 0.3457, Val_Acc: 0.8053
# EPOCH 21/100, Train_Loss: 0.5024, Train_Acc: 0.8259, Validation Loss: 0.3512, Val_Acc: 0.8080
# EPOCH 22/100, Train_Loss: 0.4874, Train_Acc: 0.8327, Validation Loss: 0.3273, Val_Acc: 0.8235
# EPOCH 23/100, Train_Loss: 0.4790, Train_Acc: 0.8381, Validation Loss: 0.3256, Val_Acc: 0.8257
# EPOCH 24/100, Train_Loss: 0.4701, Train_Acc: 0.8404, Validation Loss: 0.3265, Val_Acc: 0.8272
# EPOCH 25/100, Train_Loss: 0.4654, Train_Acc: 0.8452, Validation Loss: 0.3195, Val_Acc: 0.8323
# EPOCH 26/100, Train_Loss: 0.4523, Train_Acc: 0.8498, Validation Loss: 0.3213, Val_Acc: 0.8285
# EPOCH 27/100, Train_Loss: 0.4482, Train_Acc: 0.8518, Validation Loss: 0.3389, Val_Acc: 0.8125
# EPOCH 28/100, Train_Loss: 0.4557, Train_Acc: 0.8477, Validation Loss: 0.3211, Val_Acc: 0.8295
# EPOCH 29/100, Train_Loss: 0.4403, Train_Acc: 0.8550, Validation Loss: 0.3169, Val_Acc: 0.8322
# EPOCH 30/100, Train_Loss: 0.4369, Train_Acc: 0.8561, Validation Loss: 0.3185, Val_Acc: 0.8303
# EPOCH 31/100, Train_Loss: 0.4342, Train_Acc: 0.8573, Validation Loss: 0.3180, Val_Acc: 0.8338
# EPOCH 32/100, Train_Loss: 0.4257, Train_Acc: 0.8608, Validation Loss: 0.3098, Val_Acc: 0.8348
# EPOCH 33/100, Train_Loss: 0.4217, Train_Acc: 0.8629, Validation Loss: 0.3195, Val_Acc: 0.8297
# EPOCH 34/100, Train_Loss: 0.4139, Train_Acc: 0.8670, Validation Loss: 0.3186, Val_Acc: 0.8325
# EPOCH 35/100, Train_Loss: 0.4071, Train_Acc: 0.8697, Validation Loss: 0.3127, Val_Acc: 0.8368
# EPOCH 36/100, Train_Loss: 0.4077, Train_Acc: 0.8688, Validation Loss: 0.3185, Val_Acc: 0.8245
# EPOCH 37/100, Train_Loss: 0.4029, Train_Acc: 0.8704, Validation Loss: 0.3109, Val_Acc: 0.8393
# EPOCH 38/100, Train_Loss: 0.3934, Train_Acc: 0.8749, Validation Loss: 0.3138, Val_Acc: 0.8398
# EPOCH 39/100, Train_Loss: 0.4024, Train_Acc: 0.8695, Validation Loss: 0.3088, Val_Acc: 0.8408
# EPOCH 40/100, Train_Loss: 0.3899, Train_Acc: 0.8758, Validation Loss: 0.3075, Val_Acc: 0.8398
# EPOCH 41/100, Train_Loss: 0.3954, Train_Acc: 0.8723, Validation Loss: 0.3185, Val_Acc: 0.8378
# EPOCH 42/100, Train_Loss: 0.3881, Train_Acc: 0.8767, Validation Loss: 0.3224, Val_Acc: 0.8272
# EPOCH 43/100, Train_Loss: 0.3789, Train_Acc: 0.8797, Validation Loss: 0.3061, Val_Acc: 0.8450
# EPOCH 44/100, Train_Loss: 0.3723, Train_Acc: 0.8837, Validation Loss: 0.3052, Val_Acc: 0.8435
# EPOCH 45/100, Train_Loss: 0.3840, Train_Acc: 0.8766, Validation Loss: 0.3205, Val_Acc: 0.8320
# EPOCH 46/100, Train_Loss: 0.3717, Train_Acc: 0.8828, Validation Loss: 0.3163, Val_Acc: 0.8362
# EPOCH 47/100, Train_Loss: 0.3749, Train_Acc: 0.8811, Validation Loss: 0.3105, Val_Acc: 0.8433
# EPOCH 48/100, Train_Loss: 0.3737, Train_Acc: 0.8815, Validation Loss: 0.3108, Val_Acc: 0.8377
# EPOCH 49/100, Train_Loss: 0.3635, Train_Acc: 0.8852, Validation Loss: 0.3060, Val_Acc: 0.8453
# EPOCH 50/100, Train_Loss: 0.3606, Train_Acc: 0.8875, Validation Loss: 0.3203, Val_Acc: 0.8343
# EPOCH 51/100, Train_Loss: 0.3555, Train_Acc: 0.8888, Validation Loss: 0.3189, Val_Acc: 0.8340
# EPOCH 52/100, Train_Loss: 0.3614, Train_Acc: 0.8857, Validation Loss: 0.3132, Val_Acc: 0.8442
# EPOCH 53/100, Train_Loss: 0.3566, Train_Acc: 0.8878, Validation Loss: 0.3061, Val_Acc: 0.8482
# EPOCH 54/100, Train_Loss: 0.3496, Train_Acc: 0.8910, Validation Loss: 0.3101, Val_Acc: 0.8425
# EPOCH 55/100, Train_Loss: 0.3507, Train_Acc: 0.8910, Validation Loss: 0.3147, Val_Acc: 0.8440
# EPOCH 56/100, Train_Loss: 0.3541, Train_Acc: 0.8888, Validation Loss: 0.3157, Val_Acc: 0.8415
# EPOCH 57/100, Train_Loss: 0.3434, Train_Acc: 0.8939, Validation Loss: 0.3092, Val_Acc: 0.8445
# EPOCH 58/100, Train_Loss: 0.3409, Train_Acc: 0.8945, Validation Loss: 0.3192, Val_Acc: 0.8380
# EPOCH 59/100, Train_Loss: 0.3362, Train_Acc: 0.8968, Validation Loss: 0.3155, Val_Acc: 0.8443
# EPOCH 60/100, Train_Loss: 0.3413, Train_Acc: 0.8947, Validation Loss: 0.3101, Val_Acc: 0.8463
# EPOCH 61/100, Train_Loss: 0.3396, Train_Acc: 0.8929, Validation Loss: 0.3076, Val_Acc: 0.8483
# EPOCH 62/100, Train_Loss: 0.3285, Train_Acc: 0.9004, Validation Loss: 0.3143, Val_Acc: 0.8402
# EPOCH 63/100, Train_Loss: 0.3342, Train_Acc: 0.8968, Validation Loss: 0.3199, Val_Acc: 0.8433
# EPOCH 64/100, Train_Loss: 0.3484, Train_Acc: 0.8901, Validation Loss: 0.3095, Val_Acc: 0.8473
# EPOCH 65/100, Train_Loss: 0.3295, Train_Acc: 0.8987, Validation Loss: 0.3084, Val_Acc: 0.8490
# EPOCH 66/100, Train_Loss: 0.3208, Train_Acc: 0.9018, Validation Loss: 0.3108, Val_Acc: 0.8443
# EPOCH 67/100, Train_Loss: 0.3208, Train_Acc: 0.9016, Validation Loss: 0.3135, Val_Acc: 0.8488
# EPOCH 68/100, Train_Loss: 0.3201, Train_Acc: 0.9025, Validation Loss: 0.3131, Val_Acc: 0.8480
# EPOCH 69/100, Train_Loss: 0.3181, Train_Acc: 0.9024, Validation Loss: 0.3179, Val_Acc: 0.8477
# EPOCH 70/100, Train_Loss: 0.3189, Train_Acc: 0.9024, Validation Loss: 0.3091, Val_Acc: 0.8502
# EPOCH 71/100, Train_Loss: 0.3210, Train_Acc: 0.9015, Validation Loss: 0.3171, Val_Acc: 0.8457
# EPOCH 72/100, Train_Loss: 0.3159, Train_Acc: 0.9034, Validation Loss: 0.3216, Val_Acc: 0.8402
# EPOCH 73/100, Train_Loss: 0.3157, Train_Acc: 0.9034, Validation Loss: 0.3113, Val_Acc: 0.8477
# EPOCH 74/100, Train_Loss: 0.3111, Train_Acc: 0.9051, Validation Loss: 0.3250, Val_Acc: 0.8422
# EPOCH 75/100, Train_Loss: 0.3109, Train_Acc: 0.9057, Validation Loss: 0.3216, Val_Acc: 0.8457
# EPOCH 76/100, Train_Loss: 0.3173, Train_Acc: 0.9017, Validation Loss: 0.3612, Val_Acc: 0.8170
# EPOCH 77/100, Train_Loss: 0.3141, Train_Acc: 0.9036, Validation Loss: 0.3141, Val_Acc: 0.8478
# EPOCH 78/100, Train_Loss: 0.3125, Train_Acc: 0.9047, Validation Loss: 0.3188, Val_Acc: 0.8465
# EPOCH 79/100, Train_Loss: 0.3063, Train_Acc: 0.9069, Validation Loss: 0.3162, Val_Acc: 0.8440
# EPOCH 80/100, Train_Loss: 0.3017, Train_Acc: 0.9095, Validation Loss: 0.3170, Val_Acc: 0.8470
# EPOCH 81/100, Train_Loss: 0.3021, Train_Acc: 0.9081, Validation Loss: 0.3266, Val_Acc: 0.8438
# EPOCH 82/100, Train_Loss: 0.2999, Train_Acc: 0.9094, Validation Loss: 0.3266, Val_Acc: 0.8472
# EPOCH 83/100, Train_Loss: 0.3022, Train_Acc: 0.9077, Validation Loss: 0.3150, Val_Acc: 0.8457
# EPOCH 84/100, Train_Loss: 0.2967, Train_Acc: 0.9104, Validation Loss: 0.3182, Val_Acc: 0.8492
# EPOCH 85/100, Train_Loss: 0.3017, Train_Acc: 0.9087, Validation Loss: 0.3260, Val_Acc: 0.8467
# EPOCH 86/100, Train_Loss: 0.2971, Train_Acc: 0.9093, Validation Loss: 0.3187, Val_Acc: 0.8478
# EPOCH 87/100, Train_Loss: 0.2940, Train_Acc: 0.9119, Validation Loss: 0.3209, Val_Acc: 0.8460
# EPOCH 88/100, Train_Loss: 0.2961, Train_Acc: 0.9098, Validation Loss: 0.3319, Val_Acc: 0.8417
# EPOCH 89/100, Train_Loss: 0.2890, Train_Acc: 0.9135, Validation Loss: 0.3214, Val_Acc: 0.8492
# EPOCH 90/100, Train_Loss: 0.2855, Train_Acc: 0.9136, Validation Loss: 0.3273, Val_Acc: 0.8450
# EPOCH 91/100, Train_Loss: 0.2834, Train_Acc: 0.9153, Validation Loss: 0.3374, Val_Acc: 0.8410
# EPOCH 92/100, Train_Loss: 0.2932, Train_Acc: 0.9115, Validation Loss: 0.3298, Val_Acc: 0.8445
# EPOCH 93/100, Train_Loss: 0.2919, Train_Acc: 0.9120, Validation Loss: 0.3294, Val_Acc: 0.8367
# EPOCH 94/100, Train_Loss: 0.2803, Train_Acc: 0.9160, Validation Loss: 0.3641, Val_Acc: 0.8268
# EPOCH 95/100, Train_Loss: 0.2906, Train_Acc: 0.9119, Validation Loss: 0.3317, Val_Acc: 0.8397
# EPOCH 96/100, Train_Loss: 0.2815, Train_Acc: 0.9159, Validation Loss: 0.3260, Val_Acc: 0.8470
# EPOCH 97/100, Train_Loss: 0.2805, Train_Acc: 0.9156, Validation Loss: 0.3412, Val_Acc: 0.8408
# EPOCH 98/100, Train_Loss: 0.2825, Train_Acc: 0.9150, Validation Loss: 0.3219, Val_Acc: 0.8445
# EPOCH 99/100, Train_Loss: 0.2717, Train_Acc: 0.9194, Validation Loss: 0.3275, Val_Acc: 0.8463
# EPOCH 100/100, Train_Loss: 0.2802, Train_Acc: 0.9158, Validation Loss: 0.3270, Val_Acc: 0.8437

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 10))
ax[0, 0].plot(train_loss_lst, color='green')
ax[0, 0].set(xlabel='Epoch', ylabel='Loss')
ax[0, 0].set_title('Training Loss')

ax[0, 1].plot(val_loss_lst, color='orange')
ax[0, 1].set(xlabel='Epoch', ylabel='Loss')
ax[0, 1].set_title('Validation Loss')

ax[1, 0].plot(train_acc_lst, color='green')
ax[1, 0].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 0].set_title('Training Accuracy')

ax[1, 1].plot(val_acc_lst, color='orange')
ax[1, 1].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 1].set_title('Validation Accuracy')

plt.show()

# %% [markdown]
# ## 4.Evaluation

# %%
val_target = []
val_predict = []

model.eval()
with torch.no_grad():
    for X_val, y_val in val_loader:
        X_val = X_val.to(device)
        y_val = y_val.to(device)
        outputs = model(X_val)

        val_predict.append(outputs.cpu())
        val_target.append(y_val.cpu())

    val_predict = torch.cat(val_predict)
    val_target = torch.cat(val_target)
    val_acc = (torch.argmax(val_predict, 1) == val_target).sum().item() / len(val_target)

    print('Evaluation on val set:')
    print(f'Accuracy: {val_acc}')
# Out:
# Evaluation on val set:
# Accuracy: 0.8436666666666667

# %%
test_target = []
test_predict = []

model.eval()
with torch.no_grad():
    for X_test, y_test in test_loader:
        X_test = X_test.to(device)
        y_test = y_test.to(device)
        outputs = model(X_test)

        test_predict.append(outputs.cpu())
        test_target.append(y_test.cpu())

    test_predict = torch.cat(test_predict)
    test_target = torch.cat(test_target)
    test_acc = (torch.argmax(test_predict, 1) == test_target).sum().item() / len(test_target)

    print('Evaluation on test set:')
    print(f'Accuracy: {test_acc}')
# Out:
# Evaluation on test set:
# Accuracy: 0.834
